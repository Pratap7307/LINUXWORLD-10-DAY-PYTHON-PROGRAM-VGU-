# %%
print("Movie Ticket Booking")
available_seats = 50


name = input("Enter your name: ")
age = int(input("Enter your age: "))

if age >= 18:
    print("You are allowed to book tickets.")
   
    tickets = int(input("How many tickets do you want?: "))
    if tickets > 50:
        print("Seats are not avaiable")
    elif tickets <= 50:
        print(" enough seats available")
        print(" Do your payments and enjoy the show with or without your partners")

       
else:
    print("Sorry, you must be 18 or older to book tickets.")
# Out:
# Movie Ticket Booking
# Enter your name:  yash
# Enter your age:  19
# You are allowed to book tickets.
# How many tickets do you want?:  15
#  enough seats available
#  Do your payments and enjoy the show with or without your partners
